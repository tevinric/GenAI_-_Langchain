# %% [markdown]
# ## PDF Chat Architecture

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Streamlit app

# %% [markdown]
# The streamlit app will be able to perform the following functions:
#
# 1. Accept a PDF file for the source data
# 2. Accecpt a user prompt
# 3. Return ann answer to the user prompt

# %%
#!pip install streamlit
#!pip install altair==4.0
# Out:
# Collecting streamlit
#   Downloading streamlit-1.12.0-py2.py3-none-any.whl (9.1 MB)
# Requirement already satisfied: click>=7.0 in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (7.1.2)
# Requirement already satisfied: tornado>=5.0 in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (6.1)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.41-py3-none-any.whl (196 kB)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
# Collecting rich>=10.11.0
#   Downloading rich-13.7.0-py3-none-any.whl (240 kB)
# Collecting validators>=0.2
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (4.8.1)
# Requirement already satisfied: toml in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: python-dateutil in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (1.3.4)
# Requirement already satisfied: requests>=2.4 in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (2.26.0)
# Requirement already satisfied: numpy in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (1.22.4)
# Collecting protobuf<4,>=3.12
#   Downloading protobuf-3.20.3-cp39-cp39-win_amd64.whl (904 kB)
# Collecting tzlocal>=1.1
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Collecting altair>=3.2.0
#   Downloading altair-5.2.0-py3-none-any.whl (996 kB)
# Requirement already satisfied: packaging>=14.1 in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (8.4.0)
# Requirement already satisfied: watchdog in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (2.1.3)
# Collecting semver
#   Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: cachetools>=4.0 in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (5.3.1)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-15.0.0-cp39-cp39-win_amd64.whl (24.9 MB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\tevin\anaconda3\lib\site-packages (from streamlit) (4.9.0)
# Requirement already satisfied: jinja2 in c:\users\tevin\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\tevin\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: toolz in c:\users\tevin\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\tevin\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.6.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\tevin\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\tevin\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.2.0)
# Requirement already satisfied: setuptools in c:\users\tevin\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (58.0.4)
# Requirement already satisfied: six>=1.11.0 in c:\users\tevin\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (1.15.0)Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.9.0 which is incompatible.
# Requirement already satisfied: pytz>=2017.3 in c:\users\tevin\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2020.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tevin\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tevin\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tevin\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tevin\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tevin\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2021.10.8)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting tzdata
#   Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# Installing collected packages: smmap, mdurl, tzdata, pygments, markdown-it-py, gitdb, validators, tzlocal, semver, rich, pympler, pydeck, pyarrow, protobuf, gitpython, blinker, altair, streamlit
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.10.0
#     Uninstalling Pygments-2.10.0:
#       Successfully uninstalled Pygments-2.10.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.24.0
#     Uninstalling protobuf-4.24.0:
#       Successfully uninstalled protobuf-4.24.0
# Successfully installed altair-5.2.0 blinker-1.7.0 gitdb-4.0.11 gitpython-3.1.41 markdown-it-py-3.0.0 mdurl-0.1.2 protobuf-3.20.3 pyarrow-15.0.0 pydeck-0.8.1b0 pygments-2.17.2 pympler-1.0.1 rich-13.7.0 semver-3.0.2 smmap-5.0.1 streamlit-1.12.0 tzdata-2023.4 tzlocal-5.2 validators-0.22.0

# %% [markdown]
# ## Step 01 - Import libraries

# %%
import streamlit as st 
import pickle
from PyPDF2 import PdfReader
from langchain.llms import OpenAI
from langchain.vectorstores import FAISS
from langchain.chains.question_answering import load_qa_chain
from langchain.callbacks import get_openai_callback
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter # For splitting text into chunks
import os
# Out:
# 2024-02-04 17:27:11.282 INFO    numexpr.utils: NumExpr defaulting to 8 threads.

# %% [markdown]
# ### Step 02 - Add OpenAI API key

# %%
os.environ['OPENAI_API_KEY'] = ""

# %% [markdown]
# ### Step 03 - Create a function thats runs the streamlit application

# %%
def main():
    st.header('Chat with your PDF')
    st.sidebar.title('LLM ChatApp using Langchain')
    st.sidebar.markdown('''
    This is a LLM powered chatbot built using :
    - [Streamlit](https://docs.streamlit.io/)  
    - [Langchain](htts://python.langchain.com)
    - [OpenAI](https://platform.openai.com/docs/models) LLM Model                
    ''')
    
    # In streamlit, add a link by using [] to hold the text for the link followed by the () which holds the url
    
    st.sidebar.write('You can write something here to make more information available')



if __name__ == '__main__':
    main()
# Out:
# 2024-02-04 17:27:21.644
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\tevin\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
